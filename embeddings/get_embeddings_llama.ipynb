# %%
# %pip install --upgrade langchain
# %pip install --upgrade llama-cpp-python

from langchain.embeddings import LlamaCppEmbeddings
import numpy as np

llama_model_path = "../../llama2/llama.cpp/models/7B/ggml-model-q4_0.bin"
embeddings = LlamaCppEmbeddings(model_path=llama_model_path, n_ctx=2048)
# Out:
# llama_model_loader: loaded meta data with 16 key-value pairs and 291 tensors from ../llama2/llama.cpp/models/7B/ggml-model-q4_0.bin (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q4_0     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:               output_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:                    output.weight q6_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    4:              blk.0.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    5:              blk.0.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    6:         blk.0.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor    8:            blk.0.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor    9:              blk.0.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   10:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   11:            blk.0.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   13:              blk.1.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   14:              blk.1.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   15:         blk.1.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   17:            blk.1.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   18:              blk.1.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   19:           blk.1.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   20:            blk.1.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   22:              blk.2.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   23:              blk.2.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   24:         blk.2.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   26:            blk.2.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   27:              blk.2.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   28:           blk.2.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   29:            blk.2.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   31:              blk.3.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   32:              blk.3.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   33:         blk.3.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   35:            blk.3.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   36:              blk.3.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   37:           blk.3.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   38:            blk.3.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.4.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   40:              blk.4.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   41:              blk.4.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   42:         blk.4.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   43:            blk.4.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   44:            blk.4.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   45:              blk.4.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   46:           blk.4.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   47:            blk.4.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.5.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   49:              blk.5.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   50:              blk.5.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   51:         blk.5.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   52:            blk.5.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   53:            blk.5.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   54:              blk.5.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   55:           blk.5.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   56:            blk.5.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.6.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   58:              blk.6.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   59:              blk.6.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   60:         blk.6.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   61:            blk.6.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   62:            blk.6.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   63:              blk.6.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   64:           blk.6.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   65:            blk.6.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   67:              blk.7.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   68:              blk.7.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   69:         blk.7.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   70:            blk.7.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   71:            blk.7.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   72:              blk.7.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   73:           blk.7.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   74:            blk.7.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.8.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   76:              blk.8.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   77:              blk.8.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   78:         blk.8.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   79:            blk.8.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   80:            blk.8.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   81:              blk.8.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   82:           blk.8.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   83:            blk.8.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.9.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   85:              blk.9.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   86:              blk.9.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   87:         blk.9.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   88:            blk.9.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   89:            blk.9.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   90:              blk.9.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   91:           blk.9.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   92:            blk.9.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   93:             blk.10.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   94:             blk.10.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   95:             blk.10.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   96:        blk.10.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   97:           blk.10.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   98:           blk.10.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   99:             blk.10.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  100:          blk.10.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  101:           blk.10.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  102:             blk.11.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  103:             blk.11.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  104:             blk.11.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  105:        blk.11.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  106:           blk.11.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  107:           blk.11.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  108:             blk.11.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  109:          blk.11.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  110:           blk.11.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  111:             blk.12.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  112:             blk.12.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  113:             blk.12.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  114:        blk.12.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  115:           blk.12.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  116:           blk.12.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  117:             blk.12.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  118:          blk.12.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  119:           blk.12.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  120:             blk.13.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  121:             blk.13.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  122:             blk.13.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  123:        blk.13.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  124:           blk.13.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  125:           blk.13.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  126:             blk.13.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  127:          blk.13.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor
ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  287:           blk.31.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  288:             blk.31.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  289:          blk.31.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  290:           blk.31.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                       llama.context_length u32
# llama_model_loader: - kv   3:                     llama.embedding_length u32
# llama_model_loader: - kv   4:                          llama.block_count u32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   7:                 llama.attention.head_count u32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  10:                          general.file_type u32
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  15:               general.quantization_version u32
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_0:  225 tensors
# llama_model_loader: - type q6_K:    1 tensors
# llm_load_print_meta: format           = GGUF V2 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 2048
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 32
# llm_load_print_meta: n_layer          = 32
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-06
# llm_load_print_meta: n_ff             = 11008
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: model type       = 7B
# llm_load_print_meta: model ftype      = mostly Q4_0
# llm_load_print_meta: model params     = 6.74 B
# llm_load_print_meta: model size       = 3.56 GiB (4.54 BPW)
# llm_load_print_meta: general.name   = meta_models
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.09 MB
# llm_load_tensors: mem required  = 3647.96 MB
# ..................................................................................................
# llama_new_context_with_model: n_ctx      = 2048
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: kv self size  = 2048.00 MB
# llama_new_context_with_model: compute buffer total size = 8.31 MB
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 |

# %%
# Structure initial data
import pandas as pd

input_path = "../datasets/90minFootballTransferNewsNLP.csv"
df = pd.read_csv(input_path)
df = df[["Title","Date", "Link", "Content"]]
df = df.dropna()
# Concat columns of interest, this new column will be the base that will be embedded.
df["Combined"] = (
    "Title: " + df.Title.str.strip() + "; Content: " + df.Content.str.strip()
)
df.head(2)
# Out:
#                                                Title          Date  \
# 0  Football transfer rumours: Why Maguire's Man U...  Aug 15, 2023
# 1     Chelsea agree Romeo Lavia fee with Southampton  Aug 15, 2023
#
#                                                 Link  \
# 0  https://www.90min.com/posts/football-transfer-...
# 1  https://www.90min.com/posts/chelsea-agree-rome...
#
#                                              Content  \
# 0  90minÂ rounds up the latestÂ transfer news, ru...
# 1  Chelsea have finalised an agreement with South...
#
#                                             Combined
# 0  Title: Football transfer rumours: Why Maguire'...
# 1  Title: Chelsea agree Romeo Lavia fee with Sout...

# %%
# Check if any row in the "Combined" column is empty
empty_rows = df[df["Combined"].str.strip() == ""]
if not empty_rows.empty:
    print("Empty rows in 'Combined' column:")
    print(empty_rows)

# %%
# prepare sets

top_n = 100
df_test = df.iloc[(top_n + 1):(top_n+ 6)]
df = df.iloc[:top_n]

df.head(100)
# Out:
#                                                 Title          Date  \
# 0   Football transfer rumours: Why Maguire's Man U...  Aug 15, 2023
# 1      Chelsea agree Romeo Lavia fee with Southampton  Aug 15, 2023
# 2   Harry Maguire's proposed West Ham transfer col...  Aug 15, 2023
# 3   Southampton director breaks down Chelsea & Liv...  Aug 15, 2023
# 4          Neymar completes move from PSG to Al Hilal  Aug 15, 2023
# ..                                                ...           ...
# 95  Tottenham exploring new striker options despit...   Aug 9, 2023
# 96  Man City confident star duo will sign new cont...   Aug 9, 2023
# 97  Barcelona provide update on Ousmane Dembele's ...   Aug 8, 2023
# 98  Chelsea send summer signing to Strasbourg on loan   Aug 8, 2023
# 99  Barcelona unconcerned by Ilkay Gundogan regist...   Aug 8, 2023
#
#                                                  Link  \
# 0   https://www.90min.com/posts/football-transfer-...
# 1   https://www.90min.com/posts/chelsea-agree-rome...
# 2   https://www.90min.com/posts/harry-maguire-prop...
# 3   https://www.90min.com/posts/southampton-direct...
# 4   https://www.90min.com/posts/neymar-completes-m...
# ..                                                ...
# 95  https://www.90min.com/posts/tottenham-new-stri...
# 96  https://www.90min.com/posts/man-city-confident...
# 97  https://www.90min.com/posts/barcelona-update-o...
# 98  https://www.90min.com/posts/chelsea-send-summe...
# 99  https://www.90min.com/posts/barcelona-unconcer...
#
#                                               Content  \
# 0   90minÂ rounds up the latestÂ transfer news, ru...
# 1   Chelsea have finalised an agreement with South...
# 2   Harry Maguire's proposed transfer to West Ham ...
# 3   Southampton director Jason Wilcox has revealed...
# 4   Saudi Pro League side Al Hilal have confirmed ...
# ..                                                ...
# 95  Tottenham Hotspur are exploring opportunities ...
# 96  Manchester City believe they have convinced bo...
# 97  Barcelona vice-president Rafa Yuste has confir...
# 98  Chelsea have confirmed that winger Angelo Gabr...
# 99  Barcelona are not concerned about losing midfi...
#
#                                              Combined
# 0   Title: Football transfer rumours: Why Maguire'...
# 1   Title: Chelsea agree Romeo Lavia fee with Sout...
# 2   Title: Harry Maguire's proposed West Ham trans...
# 3   Title: Southampton director breaks down Chelse...
# 4   Title: Neymar completes move from PSG to Al Hi...
# ..                                                ...
# 95  Title: Tottenham exploring new striker options...
# 96  Title: Man City confident star duo will sign n...
# 97  Title: Barcelona provide update on Ousmane Dem...
# 98  Title: Chelsea send summer signing to Strasbou...
# 99  Title: Barcelona unconcerned by Ilkay Gundogan...
#
# [100 rows x 5 columns]

# %%
# Define a function to embed the query and handle errors
def embed_query_safe(query):
    try:
        return embeddings.embed_query(query)
    except Exception as e:
        print(f"Error embedding query: {query}")
        print(f"Error message: {str(e)}")
        return np.nan  # You can use np.nan to mark problematic embeddings

# %%
# Long process... running with 100 rows took 40 min on M1 mac

# Apply the function to the "Combined" column
df["embedding"] = df["Combined"].apply(embed_query_safe)

# Check for rows with NaN embeddings
problematic_rows = df[df["embedding"].isna()]
print("Problematic Rows:")
print(problematic_rows)

# Optionally, you can drop rows with NaN embeddings
df = df.dropna(subset=["embedding"])
df.to_csv("./results/footballTransferNewsEmbeddingsLLAMA.csv")

# Now, df should contain valid embeddings for non-problematic rows
# Out:
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24472.74 ms /   546 tokens (   44.82 ms per token,    22.31 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24555.29 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17148.23 ms /   397 tokens (   43.19 ms per token,    23.15 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 17206.55 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19185.07 ms /   443 tokens (   43.31 ms per token,    23.09 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 19248.71 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21687.04 ms /   498 tokens (   43.55 ms per token,    22.96 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21758.51 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19599.46 ms /   452 tokens (   43.36 ms per token,    23.06 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 19663.56 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 38142.22 ms /   840 tokens (   45.41 ms per token,    22.02 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 38261.98 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22895.32 ms /   524 tokens (   43.69 ms per token,    22.89 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22970.09 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =
ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 27993.90 ms /   628 tokens (   44.58 ms per token,    22.43 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 28084.73 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19986.19 ms /   464 tokens (   43.07 ms per token,    23.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20053.21 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 30651.92 ms /   683 tokens (   44.88 ms per token,    22.28 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 30750.77 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 28798.74 ms /   646 tokens (   44.58 ms per token,    22.43 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 28892.25 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 16400.25 ms /   383 tokens (   42.82 ms per token,    23.35 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 16455.57 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 20463.91 ms /   471 tokens (   43.45 ms per token,    23.02 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20531.60 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22750.45 ms /   504 tokens (   45.14 ms per token,    22.15 tokens per second)
# llama_print_timings:        eval time =    58.16 ms /     1 runs   (   58.16 ms per token,    17.19 tokens per second)
# llama_print_timings:       total time = 22883.16 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17155.86 ms /   402 tokens (   42.68 ms per token,    23.43 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 17215.13 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22398.88 ms /   516 tokens (   43.41 ms per token,    23.04 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22473.86 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 15069.36 ms /   355 tokens (   42.45 ms per token,    23.56 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 15121.48 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 27007.60 ms /   619 tokens (   43.63 ms per token,    22.92 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 27097.56 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 13217.65 ms /   312 tokens (   42.36 ms per token,    23.60 tokens per second)
# llama_print_timings:        eval time =    54.65 ms /     1 runs   (   54.65 ms per token,    18.30 tokens per second)
# llama_print_timings:       total time = 13318.66 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 15944.28 ms /   374 tokens (   42.63 ms per token,    23.46 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 15997.45 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 14043.66 ms /   331 tokens (   42.43 ms per token,    23.57 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 14092.03 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22692.87 ms /   526 tokens (   43.14 ms per token,    23.18 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22767.66 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19919.01 ms /   464 tokens (   42.93 ms per token,    23.29 tokens per second)
# llama_print_timings:        eval time =    57.32 ms /     1 runs   (   57.32 ms per token,    17.45 tokens per second)
# llama_print_timings:       total time = 20043.02 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 26660.51 ms /   610 tokens (   43.71 ms per token,    22.88 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 26748.02 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 23231.79 ms /   536 tokens (   43.34 ms per token,    23.07 tokens per second)
# llama_print_timings:        eval time =    59.45 ms /     1 runs   (   59.45 ms per token,    16.82 tokens per second)
# llama_print_timings:       total time = 23368.37 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 89125.26 ms /  1843 tokens (   48.36 ms per token,    20.68 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 89394.94 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21235.59 ms /   492 tokens (   43.16 ms per token,    23.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21307.12 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 20501.32 ms /   476 tokens (   43.07 ms per token,    23.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20570.78 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18019.67 ms /   421 tokens (   42.80 ms per token,    23.36 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18080.78 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 15347.27 ms /   362 tokens (   42.40 ms per token,    23.59 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 15400.44 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 30126.56 ms /   685 tokens (   43.98 ms per token,    22.74 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 30224.86 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19399.57 ms /   451 tokens (   43.01 ms per token,    23.25 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 19464.25 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 20306.72 ms /   468 tokens (   43.39 ms per token,    23.05 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20374.94 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 28977.91 ms /   659 tokens (   43.97 ms per token,    22.74 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 29073.45 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 26561.56 ms /   599 tokens (   44.34 ms per token,    22.55 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 26649.13 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 40388.75 ms /   893 tokens (   45.23 ms per token,    22.11 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 40519.80 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21186.39 ms /   487 tokens (   43.50 ms per token,    22.99 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21257.51 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 26445.21 ms /   589 tokens (   44.90 ms per token,    22.27 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 26532.13 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21518.80 ms /   491 tokens (   43.83 ms per token,    22.82 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21590.70 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18375.96 ms /   421 tokens (   43.65 ms per token,    22.91 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18437.94 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24053.41 ms /   544 tokens (   44.22 ms per token,    22.62 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24132.62 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 27809.64 ms /   622 tokens (   44.71 ms per token,    22.37 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 27899.55 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18053.26 ms /   416 tokens (   43.40 ms per token,    23.04 tokens per second)
# llama_print_timings:        eval time =    58.70 ms /     1 runs   (   58.70 ms per token,    17.04 tokens per second)
# llama_print_timings:       total time = 18173.50 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 14762.72 ms /   335 tokens (   44.07 ms per token,    22.69 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 14810.77 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24931.52 ms /   554 tokens (   45.00 ms per token,    22.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 25012.89 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19598.47 ms /   438 tokens (   44.75 ms per token,    22.35 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 19662.61 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 16380.73 ms /   378 tokens (   43.34 ms per token,    23.08 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 16435.73 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 15531.88 ms /   358 tokens (   43.39 ms per token,    23.05 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 15583.21 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24497.15 ms /   555 tokens (   44.14 ms per token,    22.66 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24578.23 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17923.14 ms /   414 tokens (   43.29 ms per token,    23.10 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 17982.65 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 33284.22 ms /   743 tokens (   44.80 ms per token,    22.32 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 33391.34 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 23247.04 ms /   526 tokens (   44.20 ms per token,    22.63 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 23322.55 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21850.08 ms /   486 tokens (   44.96 ms per token,    22.24 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21921.10 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22608.83 ms /   514 tokens (   43.99 ms per token,    22.73 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22683.44 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21021.72 ms /   478 tokens (   43.98 ms per token,    22.74 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21090.37 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24509.74 ms /   555 tokens (   44.16 ms per token,    22.64 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24590.76 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22214.24 ms /   504 tokens (   44.08 ms per token,    22.69 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22286.50 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 23113.61 ms /   536 tokens (   43.12 ms per token,    23.19 tokens per second)
# llama_print_timings:        eval time =    58.59 ms /     1 runs   (   58.59 ms per token,    17.07 tokens per second)
# llama_print_timings:       total time = 23248.66 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 31511.98 ms /   719 tokens (   43.83 ms per token,    22.82 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 31613.02 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 28529.90 ms /   578 tokens (   49.36 ms per token,    20.26 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 28614.29 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 16169.60 ms /   371 tokens (   43.58 ms per token,    22.94 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 16223.83 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21197.35 ms /   458 tokens (   46.28 ms per token,    21.61 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21264.15 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21463.52 ms /   478 tokens (   44.90 ms per token,    22.27 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21532.99 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 20218.75 ms /   461 tokens (   43.86 ms per token,    22.80 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20285.52 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 25825.13 ms /   583 tokens (   44.30 ms per token,    22.57 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 25908.43 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 33186.32 ms /   724 tokens (   45.84 ms per token,    21.82 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 33290.88 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18554.57 ms /   424 tokens (   43.76 ms per token,    22.85 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18615.16 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19165.24 ms /   440 tokens (   43.56 ms per token,    22.96 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 19227.93 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22159.28 ms /   451 tokens (   49.13 ms per token,    20.35 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22225.06 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18408.51 ms /   397 tokens (   46.37 ms per token,    21.57 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18466.93 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 25964.36 ms /   579 tokens (   44.84 ms per token,    22.30 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 26047.78 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 14853.78 ms /   343 tokens (   43.31 ms per token,    23.09 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 14902.84 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 27492.65 ms /   616 tokens (   44.63 ms per token,    22.41 tokens per second)
# llama_print_timings:        eval time =    60.34 ms /     1 runs   (   60.34 ms per token,    16.57 tokens per second)
# llama_print_timings:       total time = 27643.16 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 16660.72 ms /   381 tokens (   43.73 ms per token,    22.87 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 16715.73 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 19819.12 ms /   448 tokens (   44.24 ms per token,    22.60 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 19883.12 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18248.87 ms /   421 tokens (   43.35 ms per token,    23.07 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18310.09 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 12612.59 ms /   290 tokens (   43.49 ms per token,    22.99 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 12654.71 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 28848.61 ms /   648 tokens (   44.52 ms per token,    22.46 tokens per second)
# llama_print_timings:        eval time =    61.47 ms /     1 runs   (   61.47 ms per token,    16.27 tokens per second)
# llama_print_timings:       total time = 29004.88 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17838.27 ms /   405 tokens (   44.05 ms per token,    22.70 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 17897.63 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 55394.56 ms /  1174 tokens (   47.18 ms per token,    21.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 55567.86 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24232.01 ms /   547 tokens (   44.30 ms per token,    22.57 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24311.79 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22972.80 ms /   520 tokens (   44.18 ms per token,    22.64 tokens per second)
# llama_print_timings:        eval time =    63.52 ms /     1 runs   (   63.52 ms per token,    15.74 tokens per second)
# llama_print_timings:       total time = 23112.08 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 23711.93 ms /   527 tokens (   44.99 ms per token,    22.23 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 23788.53 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 20725.01 ms /   471 tokens (   44.00 ms per token,    22.73 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20792.85 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17948.71 ms /   394 tokens (   45.56 ms per token,    21.95 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18006.31 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24854.28 ms /   562 tokens (   44.22 ms per token,    22.61 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24936.20 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 22913.15 ms /   519 tokens (   44.15 ms per token,    22.65 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 22988.47 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 31487.81 ms /   704 tokens (   44.73 ms per token,    22.36 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 31589.55 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 27211.67 ms /   613 tokens (   44.39 ms per token,    22.53 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 27299.69 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 24431.36 ms /   542 tokens (   45.08 ms per token,    22.18 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 24509.92 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 25495.34 ms /   573 tokens (   44.49 ms per token,    22.47 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 25577.65 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 16263.26 ms /   379 tokens (   42.91 ms per token,    23.30 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 16318.31 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 12480.41 ms /   295 tokens (   42.31 ms per token,    23.64 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 12522.77 ms
#
# llama_print_timings:        load time =   529.02 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 21799.32 ms /   503 tokens (   43.34 ms per token,    23.07 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 21871.56 ms
# Problematic Rows:
#                                                 Title          Date  \
# 11  Every time British transfer record broken in P...  Aug 15, 2023
#
#                                                  Link  \
# 11  https://www.90min.com/posts/every-time-british...
#
#                                               Content  \
# 11  As the years go by, more and more money is bei...
#
#                                              Combined embedding
# 11  Title: Every time British transfer record brok...       NaN

# %%
# Get some test data

# Apply the function to the "Combined" column
df_test["embedding"] = df_test["Combined"].apply(embed_query_safe)

# Check for rows with NaN embeddings
problematic_rows = df_test[df_test["embedding"].isna()]
print("Problematic Rows:")
print(problematic_rows)

# Optionally, you can drop rows with NaN embeddings
df_test = df_test.dropna(subset=["embedding"])
df_test.to_csv("./results/footballTransferNewsTestEmbeddingsLLAMA.csv")
# Out:
# llama_print_timings:        load time =  3544.53 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17394.09 ms /   323 tokens (   53.85 ms per token,    18.57 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 17443.90 ms
#
# llama_print_timings:        load time =  3544.53 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 18796.27 ms /   422 tokens (   44.54 ms per token,    22.45 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 18858.20 ms
#
# llama_print_timings:        load time =  3544.53 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 17597.03 ms /   400 tokens (   43.99 ms per token,    22.73 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 17653.86 ms
#
# llama_print_timings:        load time =  3544.53 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 13189.81 ms /   306 tokens (   43.10 ms per token,    23.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 13233.25 ms
# Problematic Rows:
# Empty DataFrame
# Columns: [Title, Date, Link, Content, Combined, embedding]
# Index: []
# llama_print_timings:        load time =  3544.53 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 20525.64 ms /   467 tokens (   43.95 ms per token,    22.75 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 20591.93 ms
