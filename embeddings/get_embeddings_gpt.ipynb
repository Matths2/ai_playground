# %%
# init
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %%
# Structure initial data
import pandas as pd

input_path = "./datasets/90minFootballTransferNewsNLP.csv"
df = pd.read_csv(input_path)
df = df[["Title","Date", "Link", "Content"]]
df = df.dropna()
# Concat columns of interest, this new column will be the base that will be embedded.
df["Combined"] = (
    "Title: " + df.Title.str.strip() + "; Content: " + df.Content.str.strip()
)
df.head(2)

print(df.shape[0])
# Out:
# 6726

# %%
import tiktoken

top_n = 100
# subsample 100
df_test = df.iloc[(top_n + 1):(top_n + 6)]
df = df.iloc[:top_n]
encoding = tiktoken.get_encoding(embedding_encoding)

# omit reviews that are too long to embed
df["n_tokens"] = df.Combined.apply(lambda x: len(encoding.encode(x)))
df = df[df.n_tokens <= max_tokens].tail(top_n)
len(df)

df_test["n_tokens"] = df_test.Combined.apply(lambda x: len(encoding.encode(x)))
df_test.head(5)
# Out:
#                                                  Title         Date  \
# 101  Tottenham announce Â£13m signing of Argentina ...  Aug 8, 2023
# 102  Steven Gerrard reveals stance on Saudi Arabia ...  Aug 8, 2023
# 103  Harry Kane sets Bayern Munich transfer deadlin...  Aug 8, 2023
# 104    Micky van de Ven joins Tottenham from Wolfsburg  Aug 8, 2023
#
#                                                   Link  \
# 101  https://www.90min.com/posts/tottenham-announce...
# 102  https://www.90min.com/posts/steven-gerrard-sta...
# 103  https://www.90min.com/posts/harry-kane-bayern-...
# 104  https://www.90min.com/posts/micky-van-de-ven-j...
#
#                                                Content  \
# 101  Tottenham Hotspur have confirmed the signing o...
# 102  Liverpool legend and Al Ettifaq manager Steven...
# 103  Harry Kane has informed Tottenham that he will...
# 104  Tottenham Hotspur have announced the arrival o...
#
# ...

# %%
from openai.embeddings_utils import get_embedding

# Embed the Combined column
# This may take a few minutes
df["embedding"] = df.Combined.apply(lambda x: get_embedding(x, engine=embedding_model))
df.to_csv("./results/footballTransferNewsEmbeddings.csv")

# %%
from openai.embeddings_utils import get_embedding
# Get some test data
df_test["embedding"] = df_test.Combined.apply(lambda x: get_embedding(x, engine=embedding_model))
df_test.to_csv("./results/footballTransferNewsTestEmbeddings.csv")

# %%
df.head(5)
# Out:
#                                                Title          Date  \
# 0  Football transfer rumours: Why Maguire's Man U...  Aug 15, 2023
# 1     Chelsea agree Romeo Lavia fee with Southampton  Aug 15, 2023
# 2  Harry Maguire's proposed West Ham transfer col...  Aug 15, 2023
# 3  Southampton director breaks down Chelsea & Liv...  Aug 15, 2023
# 4         Neymar completes move from PSG to Al Hilal  Aug 15, 2023
#
#                                                 Link  \
# 0  https://www.90min.com/posts/football-transfer-...
# 1  https://www.90min.com/posts/chelsea-agree-rome...
# 2  https://www.90min.com/posts/harry-maguire-prop...
# 3  https://www.90min.com/posts/southampton-direct...
# 4  https://www.90min.com/posts/neymar-completes-m...
#
#                                              Content  \
# 0  90minÂ rounds up the latestÂ transfer news, ru...
# 1  Chelsea have finalised an agreement with South...
# 2  Harry Maguire's proposed transfer to West Ham ...
# ...
